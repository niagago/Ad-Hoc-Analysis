# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# %matplotlib inline

# %%
x = np.linspace(0, 5, 11)
y = x**2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x, y, 'm')
plt.xlabel('X Axis Title Here')
plt.ylabel('Y Axis Title Here')
plt.title('String Title Here')
plt.show()

# %%
x2 = [1,2,3,4,5]
y2 = [2,4,6,8,10]

plt.plot(x2, y2, 'c')
plt.xlabel('NOT SHY')
plt.ylabel('NOT ME')
plt.title('ITZAAAAYYY')
plt.show()

# %%
plt.subplot(1,2,1)
plt.plot(x, y, 'r--')
plt.subplot(1,2,2)
plt.plot(y,x, 'b*-')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
filename = "ncr_shs.csv"
df = pd.read_csv(filename)

df
# Out:
#         MUNICIPALITY SCHOOL ID  \
# 0        Makati City    407698
# 1        Manila City    406330
# 2        Manila City    406335
# 3      Caloocan City    400942
# 4      Caloocan City    400947
# ..               ...       ...
# 751  Valenzuela City    487015
# 752  Valenzuela City    487020
# 753  Valenzuela City    487031
# 754  Valenzuela City    487036
# 755  Valenzuela City    487048
#
#                                            SCHOOL NAME  \
# 0                    Globetek Science Foundation, Inc.
# 1                                 Lorenzo Ruiz Academy
# 2                                     Tiong Se Academy
# 3    ABE International Business College-Caloocan Ca...
# 4                   AMA Computer College-Caloocan City
# ..                                                 ...
# 751                St. Michael School of Canumay, Inc.
# 752                     Nuestra Señora de Guia Academy
# 753             St. Gregory College of Valenzuela City
# ...

# %%
df.drop(["MUNICIPALITY COUNT"], axis=1, inplace = True)

# %%
df
# Out:
#         MUNICIPALITY SCHOOL ID  \
# 0        Makati City    407698
# 1        Manila City    406330
# 2        Manila City    406335
# 3      Caloocan City    400942
# 4      Caloocan City    400947
# ..               ...       ...
# 751  Valenzuela City    487015
# 752  Valenzuela City    487020
# 753  Valenzuela City    487031
# 754  Valenzuela City    487036
# 755  Valenzuela City    487048
#
#                                            SCHOOL NAME  \
# 0                    Globetek Science Foundation, Inc.
# 1                                 Lorenzo Ruiz Academy
# 2                                     Tiong Se Academy
# 3    ABE International Business College-Caloocan Ca...
# 4                   AMA Computer College-Caloocan City
# ..                                                 ...
# 751                St. Michael School of Canumay, Inc.
# 752                     Nuestra Señora de Guia Academy
# 753             St. Gregory College of Valenzuela City
# ...

# %%
muni_count = df.loc[:,["MUNICIPALITY", "SCHOOL NAME"]].groupby(by="MUNICIPALITY", as_index=False).count().rename(columns={'SCHOOL NAME':"count"})
                                                                                                                 
muni_count=muni_count.sort_values(by="count")
muni_count
# Out:
#         MUNICIPALITY  count
# 8       Navotas City      4
# 12           Pateros      4
# 3       Malabon City     14
# 14     San Juan City     15
# 4   Mandaluyong City     19
# 10        Pasay City     22
# 16   Valenzuela City     30
# 2        Makati City     33
# 7    Muntinlupa City     35
# 6      Marikina City     35
# 15       Taguig City     36
# 11        Pasig City     39
# 1     Las Piñas City     43
# 9     Parañaque City     44
# 0      Caloocan City     77
# 5        Manila City    106
# 13       Quezon City    200

# %%
plt.barh(y=muni_count["MUNICIPALITY"], width=muni_count["count"], color='m')
plt.xlabel("Count")
plt.ylabel("Municipality")
plt.title("Schools per Municipality")
plt.show()

# %%
fig = plt.figure()
axes = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # left, bottom, width, height ---> range 0 to 1
axes.plot(x, y, 'c')
axes.set_xlabel('This is the X-Axis')
axes.set_ylabel('This is the Y-Axis')
axes.set_title('Michelle Yeoh Power')
# Out:
# Text(0.5, 1.0, 'Michelle Yeoh Power')

# %%
fig = plt.figure(figsize=(8,4), dpi=100)

# %%
fig, axes = plt.subplots(figsize=(12,3))
axes.plot(x, y, 'c')
axes.set_xlabel('This is the X-Axis')
axes.set_ylabel('This is the Y-Axis')
axes.set_title('Michelle Yeoh Power')
# Out:
# Text(0.5, 1.0, 'Michelle Yeoh Power')

# %%
fig.savefig("filename.png", dpi=300)

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1,])

ax.plot(x, x**2, label = "x squared")
ax.plot(x, x**3, label = "x cubed")
ax.legend()
